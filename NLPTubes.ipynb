# %% [markdown]
# <a href="https://colab.research.google.com/github/Hagli/NLPTubes/blob/main/NLPTubes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 50.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 25.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 86.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 24.4 MB/s eta 0:00:00

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
tokenizer("Pain.")
# Out:
# {'input_ids': [101, 3255, 1012, 102], 'token_type_ids': [0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1]}

# %%
path_to_pos = '/content/drive/MyDrive/NLPs/POS'
path_to_ner = '/content/drive/MyDrive/NLPs/NER'
path_to_score = '/content/drive/MyDrive/NLPs/Score'

# %%
from transformers import AutoModelForTokenClassification

pos = AutoModelForTokenClassification.from_pretrained(path_to_pos)

# %%
from transformers import AutoModelForTokenClassification

ner = AutoModelForTokenClassification.from_pretrained(path_to_ner)

# %%
from transformers import BertForSequenceClassification

seq = BertForSequenceClassification.from_pretrained(path_to_score)

# %%
from torch.nn import Sequential
import torch.nn as nn

class the_model(nn.Module):
    def __init__(self):
        super(the_model, self).__init__()

        self.pos_model = pos
        self.ner_model = ner
        self.base_model = seq

    def forward(self, input_ids, attn_mask):
        outputs = self.base_model(input_ids, attention_mask=attn_mask)
        # You write you new head here
        outputs = self.dropout(outputs[0])
        outputs = self.linear(outputs)

        return outputs

# %%
model(**tokenizer("Pain."))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-4c68187f1693> in <cell line: 1>()
# ----> 1 model(**tokenizer("Pain."))
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ...

# %%
from transformers import pipeline

pipe = pipeline(model=model, tokenizer=tokenizer, return_all_scores=True)
# outputs a list of dicts like [[{'label': 'NEGATIVE', 'score': 0.0001223755971295759},  {'label': 'POSITIVE', 'score': 0.9998776316642761}]]
#pipe("I love this movie!")
